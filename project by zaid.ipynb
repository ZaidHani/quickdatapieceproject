# %% [markdown]
# # this code was written by Zaid Hani Allwansah

# %% [markdown]
# ### import essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### the dataset

# %% [markdown]
# https://www.kaggle.com/datasets/arathipraj/house-data

# %%
df = pd.read_csv('house_data.csv')
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
print(df.info())
display(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df = df.drop(['id', 'date'], axis=1)

# %% [markdown]
# ## machine learning stuff

# %% [markdown]
# ### import machine learning libraries

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

from sklearn.metrics import r2_score

# %% [markdown]
# ### split data into x and y

# %%
x = df.drop(['price'], axis=1)
y = df['price']

# %% [markdown]
# ### build models

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor()
svr = SVR()

# %% [markdown]
# ### compare the models and select the best one

# %%
list_of_metrics = []
iterations = 10
for i in range(1, iterations+1):
    x_train, x_test, y_train, y_test = train_test_split(x,y)
    
    lr.fit(x_train, y_train)
    dtr.fit(x_train, y_train)
    rfr.fit(x_train, y_train)
    svr.fit(x_train, y_train)

    lr_predictions = lr.predict(x_test)
    dtr_predictions = dtr.predict(x_test)
    rfr_predictions = rfr.predict(x_test)
    svr_predictions = svr.predict(x_test)
    
    list_of_metrics.append([
        r2_score(y_test, lr_predictions),
        r2_score(y_test, dtr_predictions),
        r2_score(y_test, rfr_predictions),
        r2_score(y_test, svr_predictions)]
    )
    print(f'done with {i} iterations')
# Out:
# done with 1 iterations
# done with 2 iterations
# done with 3 iterations
# done with 4 iterations
# done with 5 iterations
# done with 6 iterations
# done with 7 iterations
# done with 8 iterations
# done with 9 iterations
# done with 10 iterations

# %%
r2 = pd.DataFrame(list_of_metrics, columns=['Linear Regression', 'Decision Tree', 'Random Forest', 'SVR'])

# %%
r2
# Out:
#    Linear Regression  Decision Tree  Random Forest       SVR
# 0           0.696195       0.767184       0.876421 -0.060362
# 1           0.698849       0.770251       0.891836 -0.059762
# 2           0.696145       0.777659       0.877948 -0.061565
# 3           0.697036       0.748866       0.886000 -0.060446
# 4           0.692704       0.753685       0.865680 -0.058457
# 5           0.695432       0.752499       0.875265 -0.055604
# 6           0.689135       0.724964       0.857402 -0.061363
# 7           0.709695       0.757881       0.875148 -0.057434
# 8           0.689861       0.748529       0.878705 -0.059128
# 9           0.694554       0.720633       0.867751 -0.055209

# %%
r2.describe()
# Out:
#        Linear Regression  Decision Tree  Random Forest        SVR
# count          10.000000      10.000000      10.000000  10.000000
# mean            0.695961       0.752215       0.875216  -0.058933
# std             0.005724       0.018245       0.009875   0.002244
# min             0.689135       0.720633       0.857402  -0.061565
# 25%             0.693167       0.748613       0.869600  -0.060425
# 50%             0.695788       0.753092       0.875843  -0.059445
# 75%             0.696826       0.764858       0.878516  -0.057690
# max             0.709695       0.777659       0.891836  -0.055209

# %% [markdown]
# ##### as you can see the random forest regressor is the model wtih the best performance

# %%
real_data = [[3, 3, 1937, 1137, 1, 0, 1, 4, 4, 1788, 0, 2018, 0, 11123, 31.945368, 35.928371, 685.391304, 27304.179631]]
real = pd.DataFrame(real_data, columns=x.columns)
real
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3          3         1937      1137       1           0     1
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          4      4        1788              0      2018             0
#
#    zipcode        lat       long  sqft_living15    sqft_lot15
# 0    11123  31.945368  35.928371     685.391304  27304.179631

# %%
print(rfr.predict(real)[0])
# Out:
# 343586.5

# %% [markdown]
# #### $347184.93

# %% [markdown]
# #### $335702.33

# %% [markdown]
# #### $316409.01

# %% [markdown]
# #### $339107.43

# %% [markdown]
# #### $343586.5

# %%
np.mean([347184.93, 335702.33, 316409.01, 339107.43, 343586.5])
# Out:
# 336398.04

# %% [markdown]
# # $336_398.04
